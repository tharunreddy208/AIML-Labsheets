# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('/content/sample_data/advertising/advertising.xlsx')

# %%
df.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
print(df.shape)
# Out:
# (200, 4)

# %%
print(df.describe())
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
fig, axs =plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(df['TV'], ax = axs[0])
plt2 = sns.boxplot(df['Newspaper'], ax = axs[1])
plt3 = sns.boxplot(df['Radio'], ax = axs[2])
plt.tight_layout()

# %%
X = df['TV']
y = df['Sales']

# %%
plt.scatter(X,y, color = 'blue', label='Scatter Plot')
plt.title('Relationship Between TV and Sales')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
print(X.shape)
print(y.shape)
# Out:
# (200,)
# (200,)

# %%
X=np.array(X)
y=np.array(y)

# %%
X=X.reshape(-1,1)
y=y.reshape(-1,1)

# %%
print(X.shape)
print(y.shape)
# Out:
# (200, 1)
# (200, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test,=train_test_split(X,y,test_size=0.30,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (140, 1)
# (60, 1)
# (140, 1)
# (60, 1)

# %%
from sklearn.linear_model import LinearRegression # import the model class

model = LinearRegression() # create an instance of the model and assign it to the variable model
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
plt.scatter(X_train, y_train,color = 'red')
plt.plot(X_train, model.predict(X_train),color='blue')
plt.title('training data')
plt.Xlable('TV')
plt.ylabel('Sales')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-ba0aefd4f5ab> in <cell line: 4>()
#       2 plt.plot(X_train, model.predict(X_train),color='blue')
#       3 plt.title('training data')
# ----> 4 plt.Xlable('TV')
#       5 plt.ylabel('Sales')
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'Xlable'

# %%
slope = model.coef_
intercept = odel.intercept_,
print("Estimated model slope:",slope)
